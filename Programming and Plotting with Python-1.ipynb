# %% [markdown]
# # Variables and Assignments

# %%
age = 42
first_name = 'Sara'
last_name = 'Li'

# %%
print(first_name, 'is', age, 'years old')
# Out:
# Sara is 42 years old

# %%
print(first_name,last_name, 'is', age, 'years old')
# Out:
# Sara Li is 42 years old

# %% [markdown]
# # Data types and Type Conversion

# %%
type(52)
# Out:
# int

# %%
type(3.4)
# Out:
# float

# %%
type('word')
# Out:
# str

# %%
5 - 3
# Out:
# 2

# %%
"Temperature" - "T"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-cfa04a103194> in <module>()
# ----> 1 "Temperature" - "T"
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
2 + 3
# Out:
# 5

# %%
'Sara' + "Li"
# Out:
# 'SaraLi'

# %%
'Sara' + ' ' + "Li"
# Out:
# 'Sara Li'

# %%
number = '1'+'2'

# %%
number = int(number)*2

# %%
type(number)
# Out:
# int

# %%
'vardahagh'+ str(number)
# Out:
# 'vardahagh24'

# %%
3.14 + 1
# Out:
# 4.140000000000001

# %%
3.14/ 2
# Out:
# 1.57

# %%
int(3.00 + 1 )
# Out:
# 4

# %%
4 / 2
# Out:
# 2.0

# %%
4 // 2
# Out:
# 2

# %%
4.3 // 2
# Out:
# 2.0

# %%
5 % 3
# Out:
# 2

# %% [markdown]
# # Built in functions in python

# %%
number_list = [1, 2, 3, 4, 5]

# %%
max(number_list)
# Out:
# 5

# %%
min(number_list)
# Out:
# 1

# %%
round(3.712)
# Out:
# 4

# %%
round (3.712, 1)
# Out:
# 3.7

# %%
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(...)
#     round(number[, ndigits]) -> number
#
#     Round a number to a given precision in decimal digits (default 0 digits).
#     This returns an int when called with one argument, otherwise the
#     same type as the number. ndigits may be negative.

# %%
help(max)
# Out:
# Help on built-in function max in module builtins:
#
# max(...)
#     max(iterable, *[, default=obj, key=func]) -> value
#     max(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its biggest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more arguments, return the largest argument.

# %% [markdown]
# # Lists and indexing

# %%
pressure = [0.273, 0.275, 0.280, 0.285, 0.3]

# %%
temperature = [300, 305, 310, 312, 400]

# %%
combined  = temperature + pressure

# %%
combined
# Out:
# [300, 305, 310, 312, 400, 0.273, 0.275, 0.28, 0.285, 0.3]

# %%
combined[2:6]
# Out:
# [310, 312, 400, 0.273]

# %%
combined [5:-2]
# Out:
# [0.273, 0.275, 0.28]

# %%
combined [:5]
# Out:
# [300, 305, 310, 312, 400]

# %%
name = 'Sara'

# %%
name[0]
# Out:
# 'S'

# %%
test_number= 64786756473674

# %%
test_number[5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-9493d946d01c> in <module>()
# ----> 1 test_number[5]
#
# TypeError: 'int' object is not subscriptable

# %%
primes = [2, 3, 5]

# %%
primes.append(7)

# %%
primes
# Out:
# [2, 3, 5, 7]

# %%
primes.extend([11, 13, 17])

# %%
primes
# Out:
# [2, 3, 5, 7, 11, 13, 17]

# %%
del primes [3]

# %%
primes
# Out:
# [2, 3, 5, 11, 13, 17]

# %%
del primes[1:3]

# %%
primes
# Out:
# [2, 11, 13, 17]

# %%
pressure
# Out:
# [0.273, 0.275, 0.28, 0.285, 0.3]

# %%
pressure [1] = 0.278

# %%
pressure
# Out:
# [0.273, 0.278, 0.28, 0.285, 0.3]

# %% [markdown]
# # Practice:
#
# 1. create a list with 10 float numbers
# 2. create a second list with 5 integer numbers
# 3. combine the two lists as one list
# 4. delete the first and last items on the combined list
# 5. replace the minimum of the list with 100

# %%
list1 = [2.3, 45.5, 67.6, 2.5, 89.65, 0.11, 145., 1.99, 578.67, 88.]
len(list1)
# Out:
# 10

# %%
list2 = [67,34, 101, 11, 45]
len(list2)
# Out:
# 5

# %%
list1.extend(list2)

# %%
combined = list1

# %%
list(combined)
# Out:
# [2.3,
#  45.5,
#  67.6,
#  2.5,
#  89.65,
#  0.11,
#  145.0,
#  1.99,
#  578.67,
#  88.0,
#  67,
#  34,
#  101,
#  11,
#  45]

# %%
del combined[0]

# %%
del combined[-1]

# %%
combined
# Out:
# [45.5, 67.6, 2.5, 89.65, 0.11, 145.0, 1.99, 578.67, 88.0, 67, 34, 101, 11]

# %%
min(combined)
# Out:
# 0.11

# %%
min_idx = combined.index(0.11)

# %%
combined [min_idx] = 100

# %%
combined
# Out:
# [45.5, 67.6, 2.5, 89.65, 100, 145.0, 1.99, 578.67, 88.0, 67, 34, 101, 11]

# %%
test_list = [67, 45, 1, 2, 5, 1, 6]
test_list.index(min(test_list))
# Out:
# 2

# %% [markdown]
# # Libraries

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.cos(math.pi)
# Out:
# -1.0

# %%
help(math)
# Out:
# Help on module math:
#
# NAME
#     math
#
# MODULE REFERENCE
#     https://docs.python.org/3.6/library/math
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module is always available.  It provides access to the
#     mathematical functions defined by the C standard.
#
# FUNCTIONS
#     acos(...)
#         acos(x)
#
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(...)
#         acosh(x)
#
#         Return the inverse hyperbolic cosine of x.
#
#     asin(...)
#         asin(x)
#
#         Return the arc sine (measured in radians) of x.
#
#     asinh(...)
#         asinh(x)
#
#         Return the inverse hyperbolic sine of x.
#
#     atan(...)
# ...

# %%
import math as m

# %%
m.pi
# Out:
# 3.141592653589793

# %%
import numpy as np

# %% [markdown]
# # Reading tabular data

# %%
import pandas as pd

# %%
data = pd.read_csv('./gapminder_gdp_oceania.csv', index_col = 'country')

# %%
data
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, Australia to New Zealand
# Data columns (total 12 columns):
# gdpPercap_1952    2 non-null float64
# gdpPercap_1957    2 non-null float64
# gdpPercap_1962    2 non-null float64
# gdpPercap_1967    2 non-null float64
# gdpPercap_1972    2 non-null float64
# gdpPercap_1977    2 non-null float64
# gdpPercap_1982    2 non-null float64
# gdpPercap_1987    2 non-null float64
# gdpPercap_1992    2 non-null float64
# gdpPercap_1997    2 non-null float64
# gdpPercap_2002    2 non-null float64
# gdpPercap_2007    2 non-null float64
# dtypes: float64(12)
# memory usage: 208.0+ bytes

# %%
data.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        2.000000        2.000000        2.000000        2.000000
# mean     10298.085650    11598.522455    12696.452430    14495.021790
# std        365.560078      917.644806      677.727301       43.986086
# min      10039.595640    10949.649590    12217.226860    14463.918930
# 25%      10168.840645    11274.086022    12456.839645    14479.470360
# 50%      10298.085650    11598.522455    12696.452430    14495.021790
# 75%      10427.330655    11922.958888    12936.065215    14510.573220
# max      10556.575660    12247.395320    13175.678000    14526.124650
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count         2.00000        2.000000        2.000000        2.000000
# mean      16417.33338    17283.957605    18554.709840    20448.040160
# std         525.09198     1485.263517     1304.328377     2037.668013
# ...

# %%
data.T
# Out:
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686  13175.67800
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728
# gdpPercap_1977  18334.19751  16233.71770
# gdpPercap_1982  19477.00928  17632.41040
# gdpPercap_1987  21888.88903  19007.19129
# gdpPercap_1992  23424.76683  18363.32494
# gdpPercap_1997  26997.93657  21050.41377
# gdpPercap_2002  30687.75473  23189.80135
# gdpPercap_2007  34435.36744  25185.00911

# %%
americas = pd.read_csv('./gapminder_gdp_americas.csv',index_col = 'country')
americas
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina            Americas     5911.315053     6856.856212     7133.166023
# Bolivia              Americas     2677.326347     2127.686326     2180.972546
# Brazil               Americas     2108.944355     2487.365989     3336.585802
# Canada               Americas    11367.161120    12489.950060    13462.485550
# Chile                Americas     3939.978789     4315.622723     4519.094331
# Colombia             Americas     2144.115096     2323.805581     2492.351109
# Costa Rica           Americas     2627.009471     2990.010802     3460.937025
# Cuba                 Americas     5586.538780     6092.174359     5180.755910
# Dominican Republic   Americas     1397.717137     1544.402995     1662.137359
# Ecuador              Americas     3522.110717     3780.546651     4086.114078
# El Salvador          Americas     3048.302900     3421.523218     3776.803627
# ...

# %%
americas.head()
# Out:
#           continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina  Americas     5911.315053     6856.856212     7133.166023
# Bolivia    Americas     2677.326347     2127.686326     2180.972546
# Brazil     Americas     2108.944355     2487.365989     3336.585802
# Canada     Americas    11367.161120    12489.950060    13462.485550
# Chile      Americas     3939.978789     4315.622723     4519.094331
#
#            gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Argentina     8052.953021     9443.038526    10079.026740     8997.897412
# Bolivia       2586.886053     2980.331339     3548.097832     3156.510452
# Brazil        3429.864357     4985.711467     6660.118654     7030.835878
# Canada       16076.588030    18970.570860    22090.883060    22898.792140
# Chile         5106.654313     5494.024437     4756.763836     5095.665738
#
#            gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# country
# ...

# %%
americas.tail()
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Puerto Rico          Americas     3081.959785     3907.156189     5108.344630
# Trinidad and Tobago  Americas     3023.271928     4100.393400     4997.523971
# United States        Americas    13990.482080    14847.127120    16173.145860
# Uruguay              Americas     5716.766744     6150.772969     5603.357717
# Venezuela            Americas     7689.799761     9802.466526     8422.974165
#
#                      gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Puerto Rico             6929.277714     9123.041742     9770.524921
# Trinidad and Tobago     5621.368472     6619.551419     7899.554209
# United States          19530.365570    21806.035940    24072.632130
# Uruguay                 5444.619620     5703.408898     6504.339663
# Venezuela               9541.474188    10505.259660    13143.950950
#
# ...

# %%
americas.head(8)
# Out:
#            continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina   Americas     5911.315053     6856.856212     7133.166023
# Bolivia     Americas     2677.326347     2127.686326     2180.972546
# Brazil      Americas     2108.944355     2487.365989     3336.585802
# Canada      Americas    11367.161120    12489.950060    13462.485550
# Chile       Americas     3939.978789     4315.622723     4519.094331
# Colombia    Americas     2144.115096     2323.805581     2492.351109
# Costa Rica  Americas     2627.009471     2990.010802     3460.937025
# Cuba        Americas     5586.538780     6092.174359     5180.755910
#
#             gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Argentina      8052.953021     9443.038526    10079.026740     8997.897412
# Bolivia        2586.886053     2980.331339     3548.097832     3156.510452
# Brazil         3429.864357     4985.711467     6660.118654     7030.835878
# ...

# %% [markdown]
# # Indexing and Slicing Pandas DataFrames

# %%
data
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
americas
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina            Americas     5911.315053     6856.856212     7133.166023
# Bolivia              Americas     2677.326347     2127.686326     2180.972546
# Brazil               Americas     2108.944355     2487.365989     3336.585802
# Canada               Americas    11367.161120    12489.950060    13462.485550
# Chile                Americas     3939.978789     4315.622723     4519.094331
# Colombia             Americas     2144.115096     2323.805581     2492.351109
# Costa Rica           Americas     2627.009471     2990.010802     3460.937025
# Cuba                 Americas     5586.538780     6092.174359     5180.755910
# Dominican Republic   Americas     1397.717137     1544.402995     1662.137359
# Ecuador              Americas     3522.110717     3780.546651     4086.114078
# El Salvador          Americas     3048.302900     3421.523218     3776.803627
# ...

# %%
data.iloc[1,5]
# Out:
# 16233.7177

# %%
americas.loc['Cuba', 'gdpPercap_1957']
# Out:
# 6092.174359000001

# %%
test_df = americas.loc['Brazil':'Cuba','gdpPercap_1957':'gdpPercap_1972' ]

# %%
test_df[test_df > 5000].describe()
# Out:
#        gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# count        2.000000        2.000000        3.000000        4.000000
# mean      9291.062209     9321.620730     8957.836786     8722.046873
# std       4523.910583     5856.067188     6171.921556     6834.072337
# min       6092.174359     5180.755910     5106.654313     5118.146939
# 25%       7691.618284     7251.188320     5398.461164     5258.620677
# 50%       9291.062209     9321.620730     5690.268015     5399.734846
# 75%      10890.506135    11392.053140    10883.428023     8863.161043
# max      12489.950060    13462.485550    16076.588030    18970.570860

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, Brazil to Cuba
# Data columns (total 4 columns):
# gdpPercap_1957    6 non-null float64
# gdpPercap_1962    6 non-null float64
# gdpPercap_1967    6 non-null float64
# gdpPercap_1972    6 non-null float64
# dtypes: float64(4)
# memory usage: 240.0+ bytes

# %%
test_df.shape
# Out:
# (6, 4)

# %%
americas.shape
# Out:
# (25, 13)

# %%
test_df.idxmax()
# Out:
# gdpPercap_1957    Canada
# gdpPercap_1962    Canada
# gdpPercap_1967    Canada
# gdpPercap_1972    Canada
# dtype: object

# %%
test_df
# Out:
#             gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Brazil         2487.365989     3336.585802     3429.864357     4985.711467
# Canada        12489.950060    13462.485550    16076.588030    18970.570860
# Chile          4315.622723     4519.094331     5106.654313     5494.024437
# Colombia       2323.805581     2492.351109     2678.729839     3264.660041
# Costa Rica     2990.010802     3460.937025     4161.727834     5118.146939
# Cuba           6092.174359     5180.755910     5690.268015     5305.445256

# %%
del americas['continent']

# %%
americas.idxmax()
# Out:
# gdpPercap_1952    United States
# gdpPercap_1957    United States
# gdpPercap_1962    United States
# gdpPercap_1967    United States
# gdpPercap_1972    United States
# gdpPercap_1977    United States
# gdpPercap_1982    United States
# gdpPercap_1987    United States
# gdpPercap_1992    United States
# gdpPercap_1997    United States
# gdpPercap_2002    United States
# gdpPercap_2007    United States
# dtype: object

# %%
test_df.idxmax()
# Out:
# gdpPercap_1957    Canada
# gdpPercap_1962    Canada
# gdpPercap_1967    Canada
# gdpPercap_1972    Canada
# dtype: object

# %%
first  = pd.read_csv('gapminder_all.csv', index_col = 'country')

# %%
first
# Out:
#                          continent  gdpPercap_1952  gdpPercap_1957  \
# country
# Algeria                     Africa     2449.008185     3013.976023
# Angola                      Africa     3520.610273     3827.940465
# Benin                       Africa     1062.752200      959.601080
# Botswana                    Africa      851.241141      918.232535
# Burkina Faso                Africa      543.255241      617.183465
# Burundi                     Africa      339.296459      379.564628
# Cameroon                    Africa     1172.667655     1313.048099
# Central African Republic    Africa     1071.310713     1190.844328
# Chad                        Africa     1178.665927     1308.495577
# Comoros                     Africa     1102.990936     1211.148548
# Congo Dem. Rep.             Africa      780.542326      905.860230
# Congo Rep.                  Africa     2125.621418     2315.056572
# Cote d'Ivoire               Africa     1388.594732     1500.895925
# ...

# %%
second = first[first['continent'] == 'Americas']

# %%
second
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina            Americas     5911.315053     6856.856212     7133.166023
# Bolivia              Americas     2677.326347     2127.686326     2180.972546
# Brazil               Americas     2108.944355     2487.365989     3336.585802
# Canada               Americas    11367.161120    12489.950060    13462.485550
# Chile                Americas     3939.978789     4315.622723     4519.094331
# Colombia             Americas     2144.115096     2323.805581     2492.351109
# Costa Rica           Americas     2627.009471     2990.010802     3460.937025
# Cuba                 Americas     5586.538780     6092.174359     5180.755910
# Dominican Republic   Americas     1397.717137     1544.402995     1662.137359
# Ecuador              Americas     3522.110717     3780.546651     4086.114078
# El Salvador          Americas     3048.302900     3421.523218     3776.803627
# ...

# %%
third = second.drop('Puerto Rico')

# %%
fourth = third.drop(columns = 'continent')

# %%
fourth.to_csv('Results.csv')

# %% [markdown]
# # commenting:
# Always rememebr to comment on your code and document it properly!

# %%
# This is an emxample
2*3 # multiplication
# Out:
# 6

# %% [markdown]
# # Plotting

# %%
import matplotlib.pyplot as plt 
% matplotlib inline

# %%
time = [0, 1, 2, 3, 4]
positions = [10, 20, 30, 40, 50]
plt.plot(time, positions)
plt.xlabel('Time (hr)')
plt.ylabel('Positions (Km)')
# Out:
# Text(0,0.5,'Positions (Km)')

# %%
years = data.columns.str.strip('gdpPercap_')
data.columns = years.astype(int)

# %%
data.loc['Australia'].plot()

# %%
data
# Out:
#                     1952         1957         1962         1967         1972  \
# country
# Australia    10039.59564  10949.64959  12217.22686  14526.12465  16788.62948
# New Zealand  10556.57566  12247.39532  13175.67800  14463.91893  16046.03728
#
#                     1977         1982         1987         1992         1997  \
# country
# Australia    18334.19751  19477.00928  21888.88903  23424.76683  26997.93657
# New Zealand  16233.71770  17632.41040  19007.19129  18363.32494  21050.41377
#
#                     2002         2007
# country
# Australia    30687.75473  34435.36744
# New Zealand  23189.80135  25185.00911

# %%
data.T.plot()

# %%
plt.xkcd()
data.T.plot(kind = 'bar')
plt.ylabel('GDP Per Capita')
plt.xlabel('Years')
# Out:
# Text(0.5,0,'Years')

# %%
data.loc['Australia'].plot(c = 'r', label = 'Australia')
data.loc['New Zealand'].plot(c = 'b', label = 'New Zealand')
plt.legend(loc = 'upper left')

# %%
gdp_aus = data.loc['Australia']
gdp_nz = data.loc['New Zealand']

# %%
plt.scatter(gdp_aus, gdp_nz)
plt.xlabel('Aus')
plt.ylabel('NZ')
# Out:
# Text(0,0.5,'NZ')

# %% [markdown]
# #### The correlation between life expectancy and gpd per capita in 2007

# %%
data_all = pd.read_csv('./gapminder_all.csv',index_col = 'country')

# %%
plt.figure()
data_all.plot(kind = 'scatter',x = 'gdpPercap_2007',y = 'lifeExp_2007',s = data_all['pop_2007']/1e6, c= 'r')
plt.savefig('./test.png')
